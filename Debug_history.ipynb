# %% [markdown]
# <a href="https://colab.research.google.com/github/FunkyDonkey065/Facade_aesthetic_evaluator/blob/main/Debug_history.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##DEBUG

# %% [markdown]
# ##2025/11/04 1. Python version mismatch between huggingface and Google colab
#
# *   change the colab python version in the runtime. ineffective due to limited python version selection
# *   change the huggingface python version in space file, readme.md, add python version info (default it is python 3.10)

# %% [markdown]
# ##2025/11/04 2. missing files for gradio
#
#
# *   All files including in the gradio should be included in the uploaded directory, for example, the example images

# %% [markdown]
# ## 2025/11/04 3. huggingface API no response
#
# *   First post to send the message, after getting the even id, use fetch to get response
#
#
# *   ```curl -X POST https://softycanine-minima.hf.space/gradio_api/call/predict -s -H "Content-Type: application/json" -d '{```
#
# *   ```curl -N https://softycanine-minima.hf.space/gradio_api/call/predict/$EVENT_ID```
